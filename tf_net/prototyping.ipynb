# %%
# %load_ext autoreload
# %autoreload 2

# %%
import train_tfnet as tfnet
from architectures.BaseNet import Net
from architectures.BPnetalike import BPnetalike

# %%
tfnet.train("DUXA",net=BPnetalike,batchsize=16,epochs=1,folds=5,subsample=True,subfolder="BPnetalike/")
# Out:
#   0%|          | 0/19995 [00:00<?, ?it/s]C:\Software\Python\Python39\lib\site-packages\torch\nn\modules\conv.py:439: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  ..\aten\src\ATen\native\Convolution.cpp:660.)
#   return F.conv2d(input, weight, bias, self.stride,
# 100%|██████████| 19995/19995 [02:41<00:00, 123.63it/s]
# ---- Fold  0  -----
#
# Accuracy of the network: 50 %
# Accuracy for class 0 with 8086 hits of 8086 is: 100.0 %
# Accuracy for class 1 with 0 hits of 7909 is: 0.0 %
#
# ---- Fold  1  -----
#
# Accuracy of the network: 49 %
# Accuracy for class 0 with 7989 hits of 7989 is: 100.0 %
# Accuracy for class 1 with 0 hits of 8006 is: 0.0 %
#
# ---- Fold  2  -----
#
# Accuracy of the network: 49 %
# Accuracy for class 0 with 0 hits of 8002 is: 0.0 %
# Accuracy for class 1 with 7993 hits of 7993 is: 100.0 %
#
# ---- Fold  3  -----
#
# Accuracy of the network: 49 %
# ...

# %%
tfnet.train("DUXA",net=Net,batchsize=16,epochs=1,folds=5,subsample=True,subfolder="Net/")
# Out:
# 100%|██████████| 19995/19995 [02:12<00:00, 150.88it/s]
# ---- Fold  0  -----
#
# Accuracy of the network: 90 %
# Accuracy for class 0 with 7716 hits of 8026 is: 96.1 %
# Accuracy for class 1 with 6825 hits of 7969 is: 85.6 %
#
# ---- Fold  1  -----
#
# Accuracy of the network: 91 %
# Accuracy for class 0 with 7761 hits of 8010 is: 96.9 %
# Accuracy for class 1 with 6857 hits of 7985 is: 85.9 %
#
# ---- Fold  2  -----
#
# Accuracy of the network: 92 %
# Accuracy for class 0 with 7410 hits of 7878 is: 94.1 %
# Accuracy for class 1 with 7448 hits of 8117 is: 91.8 %
#
# ---- Fold  3  -----
#
# Accuracy of the network: 93 %
# Accuracy for class 0 with 7363 hits of 8012 is: 91.9 %
# Accuracy for class 1 with 7534 hits of 7983 is: 94.4 %
#
# ---- Fold  4  -----
#
# Accuracy of the network: 94 %
# Accuracy for class 0 with 7795 hits of 8062 is: 96.7 %
# Accuracy for class 1 with 7283 hits of 7933 is: 91.8 %
# Finished Training DUXA

# %%
tfnet.train("ATF2",net=BPnetalike,batchsize=16,epochs=1,folds=5,subsample=True,subfolder="BPnetalike/")
# Out:
# 100%|██████████| 19995/19995 [02:34<00:00, 129.46it/s]
# ---- Fold  0  -----
#
# Accuracy of the network: 49 %
# Accuracy for class 0 with 0 hits of 8061 is: 0.0 %
# Accuracy for class 1 with 7931 hits of 7931 is: 100.0 %
#
# ---- Fold  1  -----
#
# Accuracy of the network: 49 %
# Accuracy for class 0 with 0 hits of 8086 is: 0.0 %
# Accuracy for class 1 with 7906 hits of 7906 is: 100.0 %
#
# ---- Fold  2  -----
#
# Accuracy of the network: 50 %
# Accuracy for class 0 with 8007 hits of 8007 is: 100.0 %
# Accuracy for class 1 with 0 hits of 7985 is: 0.0 %
#
# ---- Fold  3  -----
#
# Accuracy of the network: 49 %
# Accuracy for class 0 with 7837 hits of 7837 is: 100.0 %
# Accuracy for class 1 with 0 hits of 8155 is: 0.0 %
#
# ---- Fold  4  -----
#
# Accuracy of the network: 50 %
# Accuracy for class 0 with 0 hits of 7988 is: 0.0 %
# Accuracy for class 1 with 8004 hits of 8004 is: 100.0 %
# Finished Training ATF2

# %%
tfnet.train("ATF2",net=Net,batchsize=16,epochs=1,folds=5,subsample=True,subfolder="Net/")
# Out:
# 100%|██████████| 19995/19995 [02:12<00:00, 150.98it/s]
# ---- Fold  0  -----
#
# Accuracy of the network: 52 %
# Accuracy for class 0 with 1148 hits of 8004 is: 14.3 %
# Accuracy for class 1 with 7236 hits of 7988 is: 90.6 %
#
# ---- Fold  1  -----
#
# Accuracy of the network: 56 %
# Accuracy for class 0 with 3116 hits of 8073 is: 38.6 %
# Accuracy for class 1 with 5947 hits of 7919 is: 75.1 %
#
# ---- Fold  2  -----
#
# Accuracy of the network: 70 %
# Accuracy for class 0 with 6296 hits of 7933 is: 79.4 %
# Accuracy for class 1 with 4959 hits of 8059 is: 61.5 %
#
# ---- Fold  3  -----
#
# Accuracy of the network: 72 %
# Accuracy for class 0 with 6365 hits of 8075 is: 78.8 %
# Accuracy for class 1 with 5305 hits of 7917 is: 67.0 %
#
# ---- Fold  4  -----
#
# Accuracy of the network: 72 %
# Accuracy for class 0 with 5776 hits of 7895 is: 73.2 %
# Accuracy for class 1 with 5864 hits of 8097 is: 72.4 %
# Finished Training ATF2

# %%
tfnet.train("CEBPB",net=BPnetalike,batchsize=16,epochs=1,folds=5,subsample=True,subfolder="BPnetalike/")
# Out:
# 100%|██████████| 19990/19990 [02:33<00:00, 129.96it/s]
# ---- Fold  0  -----
#
# Accuracy of the network: 50 %
# Accuracy for class 0 with 8065 hits of 8065 is: 100.0 %
# Accuracy for class 1 with 0 hits of 7925 is: 0.0 %
#
# ---- Fold  1  -----
#
# Accuracy of the network: 49 %
# Accuracy for class 0 with 7955 hits of 7955 is: 100.0 %
# Accuracy for class 1 with 0 hits of 8035 is: 0.0 %
#
# ---- Fold  2  -----
#
# Accuracy of the network: 49 %
# Accuracy for class 0 with 0 hits of 8028 is: 0.0 %
# Accuracy for class 1 with 7962 hits of 7962 is: 100.0 %
#
# ---- Fold  3  -----
#
# Accuracy of the network: 49 %
# Accuracy for class 0 with 7936 hits of 7936 is: 100.0 %
# Accuracy for class 1 with 0 hits of 8054 is: 0.0 %
#
# ---- Fold  4  -----
#
# Accuracy of the network: 49 %
# Accuracy for class 0 with 7990 hits of 7990 is: 100.0 %
# Accuracy for class 1 with 0 hits of 8000 is: 0.0 %
# Finished Training CEBPB

# %%
tfnet.train("CEBPB",net=Net,batchsize=16,epochs=1,folds=5,subsample=True,subfolder="Net/")
# Out:
# 100%|██████████| 79955/79955 [03:01<00:00, 440.88it/s]
# ---- Fold  0  -----
#
# Accuracy of the network: 65 %
# Accuracy for class 0 with 1275 hits of 2006 is: 63.6 %
# Accuracy for class 1 with 1360 hits of 1991 is: 68.3 %
#
# ---- Fold  1  -----
#
# Accuracy of the network: 74 %
# Accuracy for class 0 with 1818 hits of 2021 is: 90.0 %
# Accuracy for class 1 with 1172 hits of 1976 is: 59.3 %
#
# ---- Fold  2  -----
#
# Accuracy of the network: 77 %
# Accuracy for class 0 with 1711 hits of 2004 is: 85.4 %
# Accuracy for class 1 with 1379 hits of 1993 is: 69.2 %
#
# ---- Fold  3  -----
#
# Accuracy of the network: 79 %
# Accuracy for class 0 with 1882 hits of 1955 is: 96.3 %
# Accuracy for class 1 with 1307 hits of 2042 is: 64.0 %
#
# ---- Fold  4  -----
#
# Accuracy of the network: 81 %
# Accuracy for class 0 with 1938 hits of 2007 is: 96.6 %
# Accuracy for class 1 with 1328 hits of 1990 is: 66.7 %
# Finished Training CEBPB

# %%
tfnet.train("ELK3",net=BPnetalike,batchsize=16,epochs=1,folds=5,subsample=True,subfolder="BPnetalike/")
# Out:
# ...
# 100%|██████████| 5000/5000 [00:40<00:00, 124.75it/s]
# ---- Fold  0  -----
#
# Accuracy of the network: 49 %
# Accuracy for class 0 with 1985 hits of 1985 is: 100.0 %
# Accuracy for class 1 with 0 hits of 2012 is: 0.0 %
#
# ---- Fold  1  -----
#
# Accuracy of the network: 50 %
# Accuracy for class 0 with 0 hits of 1996 is: 0.0 %
# Accuracy for class 1 with 2001 hits of 2001 is: 100.0 %
#
# ---- Fold  2  -----
#
# Accuracy of the network: 51 %
# Accuracy for class 0 with 1825 hits of 1987 is: 91.8 %
# Accuracy for class 1 with 226 hits of 2010 is: 11.2 %
#
# ---- Fold  3  -----
#
# Accuracy of the network: 49 %
# Accuracy for class 0 with 1990 hits of 1990 is: 100.0 %
# Accuracy for class 1 with 0 hits of 2007 is: 0.0 %
#
# ---- Fold  4  -----
#
# Accuracy of the network: 49 %
# Accuracy for class 0 with 0 hits of 2035 is: 0.0 %
# Accuracy for class 1 with 1962 hits of 1962 is: 100.0 %
# Finished Training ELK3

# %%
tfnet.train("ELK3",net=Net,batchsize=16,epochs=1,folds=5,subsample=True,subfolder="Net/")
# Out:
# ...
# 100%|██████████| 5000/5000 [00:33<00:00, 150.42it/s]
# ---- Fold  0  -----
#
# Accuracy of the network: 50 %
# Accuracy for class 0 with 1 hits of 1993 is: 0.1 %
# Accuracy for class 1 with 2004 hits of 2004 is: 100.0 %
#
# ---- Fold  1  -----
#
# Accuracy of the network: 56 %
# Accuracy for class 0 with 1859 hits of 1974 is: 94.2 %
# Accuracy for class 1 with 406 hits of 2023 is: 20.1 %
#
# ---- Fold  2  -----
#
# Accuracy of the network: 66 %
# Accuracy for class 0 with 1559 hits of 2034 is: 76.6 %
# Accuracy for class 1 with 1101 hits of 1963 is: 56.1 %
#
# ---- Fold  3  -----
#
# Accuracy of the network: 69 %
# Accuracy for class 0 with 1167 hits of 2020 is: 57.8 %
# Accuracy for class 1 with 1598 hits of 1977 is: 80.8 %
#
# ---- Fold  4  -----
#
# Accuracy of the network: 76 %
# Accuracy for class 0 with 1441 hits of 1972 is: 73.1 %
# Accuracy for class 1 with 1604 hits of 2025 is: 79.2 %
# Finished Training ELK3

# %%
from architectures.Resnet import Resnet

# %%
tfnet.train("DUXA",net=Resnet,batchsize=16,epochs=1,folds=5,subsample=True,subfolder="BPnetalike/")
